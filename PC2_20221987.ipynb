# %% [markdown]
# 1.   Nombre: Maria Fernanda Peñaranda Villalobos
# 2.   Código: 20221987

# %%
import pandas as pd
tabla="https://github.com/Maferenv/PC2/raw/refs/heads/main/HDI.xlsx"

# %%
tabla
# Out:
# 'https://github.com/Maferenv/PC2/raw/refs/heads/main/HDI.xlsx'

# %%
HDI=pd.read_excel(tabla, header=4)

# %%
HDI
# Out:
#     Unnamed: 0                                         Unnamed: 1  \
# 0     HDI rank                                            Country
# 1          NaN                                                NaN
# 2          NaN                        VERY HIGH HUMAN DEVELOPMENT
# 3            1                                        Switzerland
# 4            2                                             Norway
# ..         ...                                                ...
# 267        NaN                          Column 2: UNDESA (2022a).
# 268        NaN  Column 3: CEDLAS and World Bank (2022), ICF Ma...
# 269        NaN  Column 4: Barro and Lee (2018), ICF Macro Demo...
# 270        NaN  Column 5: IMF (2022), UNDESA (2022b), United N...
# 271        NaN  Column 6: Calculated based on data in columns ...
#
#     Human Development Index (HDI)   Unnamed: 3 Life expectancy at birth  \
# 0                            Value         NaN                  (years)
# ...

# %%
HDI_new=HDI.copy()

# %%
HDI_new.drop(columns=['Unnamed: 0','Unnamed: 3','Unnamed: 5','Unnamed: 7','Unnamed: 9','Unnamed: 11','Unnamed: 13'], inplace=True)

# %%
HDI_new
# Out:
#                                             Unnamed: 1  \
# 0                                              Country
# 1                                                  NaN
# 2                          VERY HIGH HUMAN DEVELOPMENT
# 3                                          Switzerland
# 4                                               Norway
# ..                                                 ...
# 267                          Column 2: UNDESA (2022a).
# 268  Column 3: CEDLAS and World Bank (2022), ICF Ma...
# 269  Column 4: Barro and Lee (2018), ICF Macro Demo...
# 270  Column 5: IMF (2022), UNDESA (2022b), United N...
# 271  Column 6: Calculated based on data in columns ...
#
#     Human Development Index (HDI)  Life expectancy at birth  \
# 0                            Value                  (years)
# 1                             2021                     2021
# 2                              NaN                      NaN
# ...

# %%
HDI_new = HDI_new.iloc[:225]
HDI_new
# Out:
#                                             Unnamed: 1  \
# 0                                              Country
# 1                                                  NaN
# 2                          VERY HIGH HUMAN DEVELOPMENT
# 3                                          Switzerland
# 4                                               Norway
# ..                                                 ...
# 220                     Small island developing states
# 221                                                NaN
# 222  Organisation for Economic Co-operation and Dev...
# 223                                                NaN
# 224                                              World
#
#     Human Development Index (HDI)  Life expectancy at birth  \
# 0                            Value                  (years)
# 1                             2021                     2021
# 2                              NaN                      NaN
# ...

# %%
HDI_new.rename(columns={'Unnamed: 1':'Country'}, inplace=True)
HDI_new
# Out:
# <ipython-input-138-76e34cf37ecc>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   HDI_new.rename(columns={'Unnamed: 1':'Country'}, inplace=True)
#                                                Country  \
# 0                                              Country
# 1                                                  NaN
# 2                          VERY HIGH HUMAN DEVELOPMENT
# 3                                          Switzerland
# 4                                               Norway
# ..                                                 ...
# 220                     Small island developing states
# 221                                                NaN
# 222  Organisation for Economic Co-operation and Dev...
# 223                                                NaN
# ...

# %%
HDI_new= HDI_new.iloc[:202]
HDI_new
# Out:
#                                  Country Human Development Index (HDI)   \
# 0                                Country                          Value
# 1                                    NaN                           2021
# 2            VERY HIGH HUMAN DEVELOPMENT                            NaN
# 3                            Switzerland                          0.962
# 4                                 Norway                          0.961
# ..                                   ...                            ...
# 197       OTHER COUNTRIES OR TERRITORIES                            NaN
# 198  Korea (Democratic People's Rep. of)                             ..
# 199                               Monaco                             ..
# 200                                Nauru                             ..
# 201                              Somalia                             ..
#
#     Life expectancy at birth Expected years of schooling  \
# ...

# %%
HDI_new = HDI_new.drop(columns=['HDI rank','GNI per capita rank minus HDI rank'])

# %%
HDI_new = HDI_new.drop([0,1])

# %%
HDI_new
# Out:
#                                  country Human_Development_Index  \
# 2            VERY HIGH HUMAN DEVELOPMENT                     NaN
# 3                            Switzerland                   0.962
# 4                                 Norway                   0.961
# 5                                Iceland                   0.959
# 6                 Hong Kong, China (SAR)                   0.952
# ..                                   ...                     ...
# 197       OTHER COUNTRIES OR TERRITORIES                     NaN
# 198  Korea (Democratic People's Rep. of)                      ..
# 199                               Monaco                      ..
# 200                                Nauru                      ..
# 201                              Somalia                      ..
#
#     Life_expentancy_at_birth Excpected_years_of_schooling  \
# 2                        NaN                          NaN
# 3                    83.9872                    16.500299
# ...

# %%
Nombres=['Country', 'Human_Development_Index', 'Life_expentancy_at_birth','Excpected_years_of_schooling','Mean_years_of_schooling','Gross_national_income_per_capita']

# %%
function = {old:new for old,new in zip(HDI_new.columns,Nombres)}

# %%
HDI_new.rename(columns=function, inplace=True)
HDI_new
# Out:
#                                  Country Human_Development_Index  \
# 3                            Switzerland                   0.962
# 4                                 Norway                   0.961
# 5                                Iceland                   0.959
# 6                 Hong Kong, China (SAR)                   0.952
# 7                              Australia                   0.951
# ..                                   ...                     ...
# 196                          South Sudan                   0.385
# 198  Korea (Democratic People's Rep. of)                      ..
# 199                               Monaco                      ..
# 200                                Nauru                      ..
# 201                              Somalia                      ..
#
#     Life_expentancy_at_birth Excpected_years_of_schooling  \
# 3                    83.9872                    16.500299
# 4                    83.2339                      18.1852
# ...

# %%
HDI_new=HDI_new.dropna(axis='rows',how='any', ignore_index=True)

# %%
HDI_new
# Out:
#                                  Country Human_Development_Index  \
# 0                            Switzerland                   0.962
# 1                                 Norway                   0.961
# 2                                Iceland                   0.959
# 3                 Hong Kong, China (SAR)                   0.952
# 4                              Australia                   0.951
# ..                                   ...                     ...
# 190                          South Sudan                   0.385
# 191  Korea (Democratic People's Rep. of)                      ..
# 192                               Monaco                      ..
# 193                                Nauru                      ..
# 194                              Somalia                      ..
#
#     Life_expentancy_at_birth Excpected_years_of_schooling  \
# 0                    83.9872                    16.500299
# 1                    83.2339                      18.1852
# ...
